# %% [markdown]
# ## Extraccion de datos de Coingecko

# %%
import requests
import pandas as pd

def obtener_proyectos_ai(max_paginas=10):
    categoria_id = "artificial-intelligence"
    proyectos = []
    for page in range(1, max_paginas + 1):
        url = "https://api.coingecko.com/api/v3/coins/markets"
        params = {
            "vs_currency": "usd",
            "category": categoria_id,
            "order": "market_cap_desc",
            "per_page": 50,
            "page": page
        }
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error al obtener datos de AI")
            break
        data = response.json()
        if not data:
            break
        for proyecto in data:
            proyecto["clasificacion"] = "ai"
        proyectos.extend(data)

    df_ai = pd.DataFrame(proyectos)
    return df_ai

df_ai = obtener_proyectos_ai()
print(f"Proyectos AI: {df_ai.shape[0]}")
# Out:
# Error al obtener datos de AI
# Proyectos AI: 250

# %%
df_ai.head()
# Out:
#                   id  symbol                                   name  \
# 0          bittensor     tao                              Bittensor
# 1               near    near                          NEAR Protocol
# 2  internet-computer     icp                      Internet Computer
# 3       render-token  render                                 Render
# 4           fetch-ai     fet  Artificial Superintelligence Alliance
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...     346.010000
# 1  https://coin-images.coingecko.com/coins/images...       2.350000
# 2  https://coin-images.coingecko.com/coins/images...       4.650000
# 3  https://coin-images.coingecko.com/coins/images...       4.330000
# 4  https://coin-images.coingecko.com/coins/images...       0.661379
#
#    market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  3008452659               41               7261123772    69457085.0
# ...

# %%
def obtener_proyectos_gaming(max_paginas=10):
    categoria_id = "gaming"
    proyectos = []
    for page in range(1, max_paginas + 1):
        url = "https://api.coingecko.com/api/v3/coins/markets"
        params = {
            "vs_currency": "usd",
            "category": categoria_id,
            "order": "market_cap_desc",
            "per_page": 50,
            "page": page
        }
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error al obtener datos de Gaming")
            break
        data = response.json()
        if not data:
            break
        for proyecto in data:
            proyecto["clasificacion"] = "gaming"
        proyectos.extend(data)

    df_gaming = pd.DataFrame(proyectos)
    return df_gaming

df_gaming = obtener_proyectos_gaming()
print(f"Proyectos Gaming: {df_gaming.shape[0]}")
# Out:
# Proyectos Gaming: 250

# %%
df_gaming.head()
# Out:
#              id symbol          name  \
# 0   immutable-x    imx     Immutable
# 1         floki  floki         FLOKI
# 2          gala   gala          GALA
# 3   the-sandbox   sand   The Sandbox
# 4  decentraland   mana  Decentraland
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...       0.551287
# 1  https://coin-images.coingecko.com/coins/images...       0.000075
# 2  https://coin-images.coingecko.com/coins/images...       0.015463
# 3  https://coin-images.coingecko.com/coins/images...       0.277198
# 4  https://coin-images.coingecko.com/coins/images...       0.292710
#
#    market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  1001687801               93               1102359707    31927638.0
# 1   727844082              115                753173816    73841283.0
# 2   684187260              122                684187260    42225894.0
# ...

# %%
def obtener_proyectos_rwa(max_paginas=5):
    categoria_id = "real-world-assets-rwa"
    proyectos = []
    for page in range(1, max_paginas + 1):
        url = "https://api.coingecko.com/api/v3/coins/markets"
        params = {
            "vs_currency": "usd",
            "category": categoria_id,
            "order": "market_cap_desc",
            "per_page": 50,
            "page": page
        }
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error al obtener datos de RWA")
            break
        data = response.json()
        if not data:
            break
        for proyecto in data:
            proyecto["clasificacion"] = "rwa"
        proyectos.extend(data)

    df_rwa = pd.DataFrame(proyectos)
    return df_rwa

df_rwa = obtener_proyectos_rwa()
print(f"Proyectos RWA: {df_rwa.shape[0]}")
# Out:
# Proyectos RWA: 250

# %%
df_rwa.head()
# Out:
#                                                   id symbol  \
# 0                                          chainlink   link
# 1                                            stellar    xlm
# 2  blackrock-usd-institutional-digital-liquidity-...  buidl
# 3                                       ondo-finance   ondo
# 4                                           algorand   algo
#
#                                                 name  \
# 0                                          Chainlink
# 1                                            Stellar
# 2  BlackRock USD Institutional Digital Liquidity ...
# 3                                               Ondo
# 4                                           Algorand
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...      13.960000
# 1  https://coin-images.coingecko.com/coins/images...       0.267738
# 2  https://coin-images.coingecko.com/coins/images...       1.000000
# ...

# %%
def obtener_proyectos_memes(max_paginas=10):
    categoria_id = "meme-token"
    proyectos = []
    for page in range(1, max_paginas + 1):
        url = "https://api.coingecko.com/api/v3/coins/markets"
        params = {
            "vs_currency": "usd",
            "category": categoria_id,
            "order": "market_cap_desc",
            "per_page": 50,
            "page": page
        }
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error al obtener datos de Memes")
            break
        data = response.json()
        if not data:
            break
        for proyecto in data:
            proyecto["clasificacion"] = "memes"
        proyectos.extend(data)

    df_memes = pd.DataFrame(proyectos)
    return df_memes

df_memes = obtener_proyectos_memes()
print(f"Proyectos Memes: {df_memes.shape[0]}")
# Out:
# Error al obtener datos de Memes
# Proyectos Memes: 250

# %%
df_memes.head()
# Out:
#                id symbol            name  \
# 0        dogecoin   doge        Dogecoin
# 1       shiba-inu   shib       Shiba Inu
# 2            pepe   pepe            Pepe
# 3  official-trump  trump  Official Trump
# 4            bonk   bonk            Bonk
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...       0.171527
# 1  https://coin-images.coingecko.com/coins/images...       0.000013
# 2  https://coin-images.coingecko.com/coins/images...       0.000008
# 3  https://coin-images.coingecko.com/coins/images...      11.130000
# 4  https://coin-images.coingecko.com/coins/images...       0.000017
#
#     market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  25561809093                8              25575573619   631995447.0
# 1   7517810618               21               7521056239   112467475.0
# 2   3448311211               36               3448311211   368348313.0
# ...

# %% [markdown]
# ## Combinar todos los df en uno solo

# %%
df_completo = pd.concat([df_ai, df_gaming, df_rwa, df_memes], ignore_index=True)

print(f"Total de proyectos: {df_completo.shape[0]}")
# Out:
# Total de proyectos: 1000

# %%
df_completo.head()
# Out:
#                   id  symbol                                   name  \
# 0          bittensor     tao                              Bittensor
# 1               near    near                          NEAR Protocol
# 2  internet-computer     icp                      Internet Computer
# 3       render-token  render                                 Render
# 4           fetch-ai     fet  Artificial Superintelligence Alliance
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...     346.010000
# 1  https://coin-images.coingecko.com/coins/images...       2.350000
# 2  https://coin-images.coingecko.com/coins/images...       4.650000
# 3  https://coin-images.coingecko.com/coins/images...       4.330000
# 4  https://coin-images.coingecko.com/coins/images...       0.661379
#
#      market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# ...

# %% [markdown]
# ## Extracción de Exchanges

# %%
import requests
import pandas as pd
import time

def obtener_lista_exchanges():
    url = "https://api.coingecko.com/api/v3/exchanges"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print("Error al obtener la lista de exchanges")
        return []

def obtener_monedas_por_exchange(exchange_id):
    url = f"https://api.coingecko.com/api/v3/exchanges/{exchange_id}"
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            data = response.json()
            tickers = data.get('tickers', [])
            monedas = set()
            for ticker in tickers:
                monedas.add(ticker['base'].lower())
            return list(monedas)
        else:
            print(f"[{exchange_id}] Error {response.status_code}")
            return []
    except Exception as e:
        print(f"[{exchange_id}] Excepción: {e}")
        return []

exchanges = obtener_lista_exchanges()

resultado = []
limite = 50

for i, exchange in enumerate(exchanges[:limite]):
    exchange_id = exchange['id']
    exchange_name = exchange['name']
    print(f"[{i+1}] {exchange_name} ({exchange_id})")

    monedas = obtener_monedas_por_exchange(exchange_id)
    if monedas:
        for moneda in monedas:
            resultado.append({
                "exchange": exchange_name,
                "exchange_id": exchange_id,
                "moneda": moneda
            })

    time.sleep(30)

df_exchanges_monedas = pd.DataFrame(resultado)
print(df_exchanges_monedas.head())
print(f"Total pares exchange-moneda: {df_exchanges_monedas.shape[0]}")

# %%
resultado
# Out:
# [{'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'aixbt'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'doge'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'atom'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'dydx'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'neiro'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'apt'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'parti'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'dot'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'rsr'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'xrp'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'rune'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'pendle'},
#  {'exchange': 'Binance', 'exchange_id': 'binance', 'moneda': 'bmt'},
# ...

# %%
import requests
import pandas as pd
import time

API_KEY = "03a1e360-0aa0-4577-b568-817c6946c82f"
headers = {
    "Accepts": "application/json",
    "X-CMC_PRO_API_KEY": API_KEY,
}

def obtener_criptos_en_bloques(total=1000, por_pagina=100):
    todas = []
    for start in range(1, total + 1, por_pagina):
        url = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest"
        params = {
            "start": str(start),
            "limit": str(por_pagina),
            "convert": "USD"
        }
        try:
            response = requests.get(url, headers=headers, params=params)
            data = response.json()
            monedas = data.get("data", [])
            todas.extend(monedas)
            print(f"Obtenidas {len(monedas)} monedas desde el índice {start}")
            time.sleep(2)
        except Exception as e:
            print(f"Error al obtener datos desde {start}: {e}")
            break

    df = pd.json_normalize(todas)
    return df

# Ejecutar
df_criptos = obtener_criptos_en_bloques(1000, 100)
print("Total monedas obtenidas:", df_criptos.shape[0])
# Out:
# Obtenidas 100 monedas desde el índice 1
# Obtenidas 100 monedas desde el índice 101
# Obtenidas 100 monedas desde el índice 201
# Obtenidas 100 monedas desde el índice 301
# Obtenidas 100 monedas desde el índice 401
# Obtenidas 100 monedas desde el índice 501
# Obtenidas 100 monedas desde el índice 601
# Obtenidas 100 monedas desde el índice 701
# Obtenidas 100 monedas desde el índice 801
# Obtenidas 100 monedas desde el índice 901
# Total monedas obtenidas: 1000

# %%
df_criptos
# Out:
#         id           name symbol           slug  num_market_pairs  \
# 0        1        Bitcoin    BTC        bitcoin             12056
# 1     1027       Ethereum    ETH       ethereum             10265
# 2      825    Tether USDt   USDT         tether            126624
# 3       52            XRP    XRP            xrp              1600
# 4     1839            BNB    BNB            bnb              2510
# ..     ...            ...    ...            ...               ...
# 995   8669         Sovryn    SOV         sovryn                20
# 996  29318  Worldwide USD   WUSD  worldwide-usd                38
# 997  34987       FLock.io  FLOCK       flock-io                38
# 998   2856        CEEK VR   CEEK        ceek-vr               132
# 999   8479          VAIOT    VAI          vaiot                37
#
#                    date_added  \
# 0    2010-07-13T00:00:00.000Z
# 1    2015-08-07T00:00:00.000Z
# 2    2015-02-25T00:00:00.000Z
# 3    2013-08-04T00:00:00.000Z
# ...

# %%
def obtener_exchanges_por_moneda(coin_id):
    url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/tickers"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return list({ticker['market']['name'] for ticker in data['tickers']})
    else:
        return []

exchanges_btc = obtener_exchanges_por_moneda("bitcoin")
print("Bitcoin se comercia en:", exchanges_btc)
# Out:
# Bitcoin se comercia en: ['BTSE', 'BigONE', 'bitFlyer', 'BitMart', 'Bitrue', 'Bitkub', 'Bitbank', 'WOO X', 'Bitfinex', 'Bitstamp', 'EXMO', 'bitcastle', 'Bittime', 'Coincheck', 'Backpack Exchange ', 'Crypto.com Exchange', 'Binance', 'Bit2Me', 'Azbit', 'QMall', 'Bitexlive', 'LBank', 'WhiteBIT', 'WEEX', 'Hotcoin', 'Tokenize', 'P2B', 'MEXC', 'Trubit', 'Biconomy.com', 'KuCoin', 'HTX', 'OKX', 'Deribit Spot', 'Pionex', 'PointPay', 'Bitget', 'DigiFinex', 'AscendEX (BitMax)', 'EarnBIT', 'LATOKEN', 'FMCPAY', 'Gemini', 'XT.COM', 'Gate.io', 'Kraken', 'Hibt', 'BYDFi', 'Bybit', 'CoinCatch', 'Slex', 'Coinstore', 'Bitunix', 'Tapbit', 'Bitvavo', 'itBit', 'Dex-Trade', 'Coinbase Exchange', 'Toobit', 'CoinW']

# %% [markdown]
# ## Visualizar la red creada

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

for _, row in df_completo.iterrows():
    G.add_node(row["id"], label=row["name"], clasificacion=row["clasificacion"],
               market_cap=row["market_cap"], volume=row["total_volume"])

for i, row_i in df_completo.iterrows():
    for j, row_j in df_completo.iterrows():
        if i >= j:
            continue
        if row_i["clasificacion"] == row_j["clasificacion"]:
            if (row_i["total_volume"] + row_j["total_volume"]) == 0:
                weight = 0
            else:
                weight = (row_i["market_cap"] + row_j["market_cap"]) / (row_i["total_volume"] + row_j["total_volume"])
            G.add_edge(row_i["id"], row_j["id"], tipo="categoria", weight=weight)

subgraph_nodes = list(G.nodes)
H = G.subgraph(subgraph_nodes)

color_map = {"ai": "red", "gaming": "blue", "rwa": "green", "memes": "purple"}
node_colors = [color_map[G.nodes[n]["clasificacion"]] for n in H.nodes]

plt.figure(figsize=(15, 15))
nx.draw_networkx(H, with_labels=False, node_color=node_colors, node_size=50, edge_color="gray", alpha=0.6)

plt.title("Red de Proyectos Cripto por Clasificación con Ponderación")
plt.axis("off")
plt.show()
